# %% [markdown]
# ## <center>Data Preprocessing assignment</center>

# %%
# Import libraries
import pandas as pd

# %%
# Data
raw_data = {'first_name' : ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'],
'last_name' : ['Miller', 'Jacobson', '.', 'Milner','Cooze'],
'age' : [42, 52, 36, 24, 73],
'preTestScore' : [4, 24, 31, '.', '.'],
'postTestScore' : ['25,000', '94,000', 57, 62, 70]}

# %%
# Creating dataframe
df = pd.DataFrame(raw_data,
                  columns=['first_name', 'last_name', 'age', 'preTestScore', 'postTestScore'])

df
# Out:
#   first_name last_name  age preTestScore postTestScore
# 0      Jason    Miller   42            4        25,000
# 1      Molly  Jacobson   52           24        94,000
# 2       Tina         .   36           31            57
# 3       Jake    Milner   24            .            62
# 4        Amy     Cooze   73            .            70

# %% [markdown]
# #### Save the data frame into a .csv file as project.csv

# %%
df.to_csv('project.csv', index = False)

# %% [markdown]
# #### Read the project.csv file and print the data frame.

# %%
student_df = pd.read_csv('project.csv')
student_df
# Out:
#   first_name last_name  age preTestScore postTestScore
# 0      Jason    Miller   42            4        25,000
# 1      Molly  Jacobson   52           24        94,000
# 2       Tina         .   36           31            57
# 3       Jake    Milner   24            .            62
# 4        Amy     Cooze   73            .            70

# %% [markdown]
# #### Read the project.csv file without column heading

# %%
student_df_no_heading = pd.read_csv('project.csv', header=None, skiprows=1)
student_df_no_heading
# Out:
#        0         1   2   3       4
# 0  Jason    Miller  42   4  25,000
# 1  Molly  Jacobson  52  24  94,000
# 2   Tina         .  36  31      57
# 3   Jake    Milner  24   .      62
# 4    Amy     Cooze  73   .      70

# %% [markdown]
# #### Read the project.csv file and make two index columns, namely, ‘First Name’ and ‘Last Name’.

# %%
student_df = pd.read_csv('project.csv', index_col=['first_name','last_name'])
student_df
# Out:
#                       age preTestScore postTestScore
# first_name last_name
# Jason      Miller      42            4        25,000
# Molly      Jacobson    52           24        94,000
# Tina       .           36           31            57
# Jake       Milner      24            .            62
# Amy        Cooze       73            .            70

# %% [markdown]
# #### Print the data frame in a Boolean form as True or False. True for Null/ NaN values and false for non-null values.

# %%
student_df = pd.read_csv('project.csv', na_values=['.'])
student_df.isna()
# Out:
#    first_name  last_name    age  preTestScore  postTestScore
# 0       False      False  False         False          False
# 1       False      False  False         False          False
# 2       False       True  False         False          False
# 3       False      False  False          True          False
# 4       False      False  False          True          False

# %% [markdown]
# #### Read the data frame by skipping the first 3 rows and print the data frame.

# %%
student_df = pd.read_csv('project.csv', skiprows=3, header=None)
student_df
# Out:
#       0       1   2   3   4
# 0  Tina       .  36  31  57
# 1  Jake  Milner  24   .  62
# 2   Amy   Cooze  73   .  70
